# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import threading

# %%
def bitcoin_line(time, price, n):
    plt.figure(figsize = (20,12))
    plt.ylabel("Price")
    plt.xlabel("Time")
    plt.plot(time, price)
    plt.plot(time,n)
    plt.legend(["Dataset 1", "Dataset 2"])

# %%
bitcoin_line([1,2,3,4,5],[20,30,40,50,50],[40,40,40,40,40])
upper_line(5)
threading.Timer(5.0, makegraph)
# Out:
# <Timer(Thread-17, initial)>

# %%
x1 = [1, 2, 3]


y1 = [4, 5, 6]

x2 = [1, 3, 5]


y2 = [6, 5, 4]

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.legend(["Dataset 1", "Dataset 2"])
